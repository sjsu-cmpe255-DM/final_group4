# %%
from preprocessing import data
train_data,test_data,train_labels,test_labels = data()

# %%
from sklearn.svm import LinearSVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

# %%
X_train, X_val, y_train, y_val = train_test_split(train_data,train_labels, test_size=0.1, random_state=42)

# %%
X_train.shape
# Out:
# (2250, 10000)

# %%
linearClassifier = LinearSVC()
linearClassifier.fit(X_train, y_train)
# Out:
# LinearSVC()

# %%
y_pred = linearClassifier.predict(X_val)

# %%
y_test_pred = linearClassifier.predict(test_data)

# %%
from sklearn.metrics import ConfusionMatrixDisplay

# Assuming y_test and y_pred are the true and predicted labels
ConfusionMatrixDisplay.from_predictions(y_test_pred,test_labels)
plt.title("Confusion Matrix")
plt.show()

# %%
from sklearn.metrics import precision_recall_curve
import matplotlib.pyplot as plt

# Assuming y_true (binary labels) and y_scores (probabilities or decision values)
precision, recall, thresholds = precision_recall_curve(y_true, y_scores)

plt.plot(recall, precision)
plt.title("Precision-Recall Curve")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       2 import matplotlib.pyplot as plt
#       4 # Assuming y_true (binary labels) and y_scores (probabilities or decision values)
# ----> 5 precision, recall, thresholds = precision_recall_curve(y_true, y_scores)
#       7 plt.plot(recall, precision)
#       8 plt.title("Precision-Recall Curve")
#
# NameError: name 'y_true' is not defined

# %%
print("Classification Report:")
print(classification_report(test_labels, y_test_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.40      0.28      0.33        50
#            1       0.70      0.70      0.70        50
#           10       0.39      0.30      0.34        50
#           11       0.81      0.78      0.80        50
#           12       0.63      0.90      0.74        50
#           13       0.78      0.70      0.74        50
#           14       0.74      0.86      0.80        50
#           15       0.54      0.58      0.56        50
#           16       0.31      0.34      0.33        50
#           17       0.44      0.50      0.47        50
#           18       0.30      0.44      0.36        50
#           19       0.83      0.58      0.68        50
#            2       0.57      0.70      0.63        50
#           20       0.77      0.68      0.72        50
#           21       0.84      0.84      0.84        50
#           22       0.68      0.72      0.70        50
#           23       0.74      0.84      0.79        50
#           24       0.74      0.90      0.81        50
#           25       0.84      0.42      0.56        50
#           26       0.53      0.42      0.47        50
#           27       0.81      0.70      0.75        50
#           28       0.71      0.72      0.71        50
#           29       0.98      0.94      0.96        50
#            3       0.91      0.80      0.85        50
#           30       0.96      1.00      0.98        50
#           31       0.76      0.76      0.76        50
#           32       0.87      0.92      0.89        50
#           33       0.94      0.98      0.96        50
#           34       0.70      0.86      0.77        50
#           35       0.73      0.72      0.73        50
#           36       0.49      0.34      0.40        50
#           37       0.89      1.00      0.94        50
#           38       0.87      0.68      0.76        50
#           39       0.76      0.78      0.77        50
#            4       0.82      0.56      0.67        50
#           40       0.14      0.08      0.10        50
#           41       0.68      0.50      0.57        50
#           42       0.75      0.84      0.79        50
#           43       0.59      0.84      0.69        50
#           44       0.32      0.40      0.35        50
#           45       0.89      0.80      0.84        50
#           46       0.98      1.00      0.99        50
#           47       0.37      0.30      0.33        50
#           48       0.57      0.40      0.47        50
#           49       0.73      0.66      0.69        50
#            5       0.62      0.66      0.64        50
#            6       0.43      0.40      0.42        50
#            7       0.45      0.76      0.57        50
#            8       0.49      0.42      0.45        50
#            9       0.50      0.74      0.60        50
#
#     accuracy                           0.66      2500
#    macro avg       0.67      0.66      0.66      2500
# weighted avg       0.67      0.66      0.66      2500

# %%
print("Classification Report:")
print(classification_report(y_val, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      1.00      0.89         4
#            1       1.00      1.00      1.00         4
#           10       1.00      1.00      1.00         8
#           11       1.00      1.00      1.00         3
#           12       1.00      1.00      1.00         3
#           13       0.83      1.00      0.91         5
#           14       1.00      0.86      0.92         7
#           15       0.33      0.50      0.40         2
#           16       0.33      0.67      0.44         3
#           17       1.00      0.71      0.83         7
#           18       0.67      0.40      0.50         5
#           19       0.50      0.50      0.50         4
#            2       1.00      0.88      0.93         8
#           20       1.00      1.00      1.00         8
#           21       0.88      1.00      0.93         7
#           22       1.00      1.00      1.00         4
#           23       1.00      1.00      1.00         6
#           24       1.00      0.80      0.89         5
#           25       1.00      1.00      1.00        10
#           26       0.80      1.00      0.89         4
#           27       1.00      0.82      0.90        11
#           28       0.90      1.00      0.95         9
#           29       1.00      1.00      1.00         4
#            3       1.00      0.83      0.91         6
#           30       1.00      1.00      1.00         7
#           31       0.60      1.00      0.75         3
#           32       0.50      1.00      0.67         1
#           33       1.00      1.00      1.00         3
#           34       1.00      0.33      0.50         3
#           35       1.00      1.00      1.00         5
#           36       1.00      1.00      1.00         4
#           37       1.00      1.00      1.00         5
#           38       0.80      1.00      0.89         4
#           39       0.25      0.50      0.33         2
#            4       0.80      1.00      0.89         4
#           40       0.67      0.33      0.44         6
#           41       0.67      0.40      0.50         5
#           42       0.50      1.00      0.67         2
#           43       0.00      0.00      0.00         0
#           44       1.00      0.80      0.89         5
#           45       1.00      0.88      0.93         8
#           46       1.00      1.00      1.00         6
#           47       0.25      0.50      0.33         2
#           48       1.00      0.67      0.80         3
#           49       1.00      0.67      0.80         6
#            5       0.86      0.86      0.86         7
#            6       1.00      0.55      0.71        11
#            7       0.67      1.00      0.80         2
#            8       1.00      0.80      0.89         5
#            9       0.40      1.00      0.57         4
#
#     accuracy                           0.85       250
#    macro avg       0.82      0.82      0.80       250
# weighted avg       0.90      0.85      0.85       250
# /Users/spartan/assignments/CMPE255/venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/spartan/assignments/CMPE255/venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/spartan/assignments/CMPE255/venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
a, b = 1, 2500
import random
random_integer = random.randint(a, b)

# Select the data point (a single row in the sparse matrix)
single_data_point = test_data[random_integer]

# Ensure the shape is correct (2D) if it's a single row
single_data_point = single_data_point.reshape(1, -1)

y_test_pred = linearClassifier.predict(single_data_point)

# %%
y_test_pred
# Out:
# array(['5'], dtype='<U2')

# %%
test_labels[random_integer]
# Out:
# '5'
